# %% [markdown]
# <a href="https://colab.research.google.com/github/jindu94/TaiwoRepo/blob/master/NBA_Salary_Prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# THIS IS WHERE THE BEAUTIFUL SOUP WILL BE COOKED...PLEASE I DONT LIKE TOO MUCH PEPPER.....

# %%
import pandas as pd
import numpy as  np
import matplotlib.pyplot as plt

# %%
NBA = pd.read_csv('/content/NBA Players Salaries 1920.csv')

# %%
NBA
# Out:
#       Rk                       Player   Tm        2019-20        2020-21  \
# 0      1      Stephen Curry\curryst01  GSW  40231758.00 $  43006362.00 $
# 1      2          Chris Paul\paulch01  OKC  38506482.00 $  41358814.00 $
# 2      3  Russell Westbrook\westbru01  HOU  38178000.00 $  41006000.00 $
# 3      4           John Wall\walljo01  WAS  37800000.00 $  40824000.00 $
# 4      5       James Harden\hardeja01  HOU  37800000.00 $  40824000.00 $
# ..   ...                          ...  ...            ...            ...
# 563  564     William Howard\howarwi01  UTA     50000.00 $            NaN
# 564  565      Isaiah Taylor\taylois01  TOR     50000.00 $            NaN
# 565  566        Tyler Lydon\lydonty01  SAC     50000.00 $            NaN
# 566  567    Hollis Thompson\thompho01  SAC     50000.00 $            NaN
# 567  568          Tyler Ulis\ulisty01  SAC     50000.00 $            NaN
#
#            2021-22        2022-23 2023-24 2024-25 Signed Using      Guaranteed
# ...

# %%
NBA.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 568 entries, 0 to 567
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Rk            568 non-null    int64
#  1   Player        568 non-null    object
#  2   Tm            568 non-null    object
#  3   2019-20       568 non-null    object
#  4   2020-21       349 non-null    object
#  5   2021-22       206 non-null    object
#  6   2022-23       96 non-null     object
#  7   2023-24       21 non-null     object
#  8   2024-25       3 non-null      object
#  9   Signed Using  455 non-null    object
#  10  Guaranteed    568 non-null    object
# dtypes: int64(1), object(10)
# memory usage: 48.9+ KB

# %%
NBA.isna().sum(
    
)
# Out:
# Rk                0
# Player            0
# Tm                0
# 2019-20           0
# 2020-21         219
# 2021-22         362
# 2022-23         472
# 2023-24         547
# 2024-25         565
# Signed Using    113
# Guaranteed        0
# dtype: int64

# %%
NBA.isnull().sum().sum()
# Out:
# 2278

# %%
NBA['2020-21'].mode()
# Out:
# 0    1517981.00 $
# dtype: object

# %%
NBA['2021-22'].mode()
# Out:
# 0    1782621.00 $
# dtype: object

# %%
NBA['2022-23'].mode()
# Out:
# 0    1930681.00 $
# dtype: object

# %%
NBA['2023-24'].mode()
# Out:
# 0    35970000.00 $
# 1    36270000.00 $
# dtype: object

# %%
NBA['2024-25'].mode()
# Out:
# 0    38610000.00 $
# dtype: object

# %%
NBA['Signed Using'].mode()
# Out:
# 0    1st Round Pick
# dtype: object

# %%
NBA['2021-22'].fillna(NBA['2021-22'].mode()[0],inplace = True)
NBA['2022-23'].fillna(NBA['2022-23'].mode()[0],inplace = True)
NBA['2023-24'].fillna(NBA['2023-24'].mode()[0],inplace = True)
NBA['2020-21'].fillna(NBA['2020-21'].mode()[0],inplace = True)

# %%
NBA
# Out:
#       Rk                       Player   Tm        2019-20        2020-21  \
# 0      1      Stephen Curry\curryst01  GSW  40231758.00 $  43006362.00 $
# 1      2          Chris Paul\paulch01  OKC  38506482.00 $  41358814.00 $
# 2      3  Russell Westbrook\westbru01  HOU  38178000.00 $  41006000.00 $
# 3      4           John Wall\walljo01  WAS  37800000.00 $  40824000.00 $
# 4      5       James Harden\hardeja01  HOU  37800000.00 $  40824000.00 $
# ..   ...                          ...  ...            ...            ...
# 563  564     William Howard\howarwi01  UTA     50000.00 $   1517981.00 $
# 564  565      Isaiah Taylor\taylois01  TOR     50000.00 $   1517981.00 $
# 565  566        Tyler Lydon\lydonty01  SAC     50000.00 $   1517981.00 $
# 566  567    Hollis Thompson\thompho01  SAC     50000.00 $   1517981.00 $
# 567  568          Tyler Ulis\ulisty01  SAC     50000.00 $   1517981.00 $
#
#            2021-22        2022-23        2023-24 2024-25 Signed Using  \
# ...

# %%
NBA['Signed Using'].fillna(method = 'ffill', inplace = True)

# %%
NBA
# Out:
#       Rk                       Player   Tm        2019-20        2020-21  \
# 0      1      Stephen Curry\curryst01  GSW  40231758.00 $  43006362.00 $
# 1      2          Chris Paul\paulch01  OKC  38506482.00 $  41358814.00 $
# 2      3  Russell Westbrook\westbru01  HOU  38178000.00 $  41006000.00 $
# 3      4           John Wall\walljo01  WAS  37800000.00 $  40824000.00 $
# 4      5       James Harden\hardeja01  HOU  37800000.00 $  40824000.00 $
# ..   ...                          ...  ...            ...            ...
# 563  564     William Howard\howarwi01  UTA     50000.00 $   1517981.00 $
# 564  565      Isaiah Taylor\taylois01  TOR     50000.00 $   1517981.00 $
# 565  566        Tyler Lydon\lydonty01  SAC     50000.00 $   1517981.00 $
# 566  567    Hollis Thompson\thompho01  SAC     50000.00 $   1517981.00 $
# 567  568          Tyler Ulis\ulisty01  SAC     50000.00 $   1517981.00 $
#
#            2021-22        2022-23        2023-24 2024-25    Signed Using  \
# ...

# %%
NBA['2024-25'].dropna(inplace = True)

# %%
NBA
# Out:
#       Rk                       Player   Tm        2019-20        2020-21  \
# 0      1      Stephen Curry\curryst01  GSW  40231758.00 $  43006362.00 $
# 1      2          Chris Paul\paulch01  OKC  38506482.00 $  41358814.00 $
# 2      3  Russell Westbrook\westbru01  HOU  38178000.00 $  41006000.00 $
# 3      4           John Wall\walljo01  WAS  37800000.00 $  40824000.00 $
# 4      5       James Harden\hardeja01  HOU  37800000.00 $  40824000.00 $
# ..   ...                          ...  ...            ...            ...
# 563  564     William Howard\howarwi01  UTA     50000.00 $   1517981.00 $
# 564  565      Isaiah Taylor\taylois01  TOR     50000.00 $   1517981.00 $
# 565  566        Tyler Lydon\lydonty01  SAC     50000.00 $   1517981.00 $
# 566  567    Hollis Thompson\thompho01  SAC     50000.00 $   1517981.00 $
# 567  568          Tyler Ulis\ulisty01  SAC     50000.00 $   1517981.00 $
#
#            2021-22        2022-23        2023-24 2024-25    Signed Using  \
# ...

# %%
NBA.dropna( axis = 'columns', inplace = True)

# %%
NBA
# Out:
#       Rk                       Player   Tm        2019-20        2020-21  \
# 0      1      Stephen Curry\curryst01  GSW  40231758.00 $  43006362.00 $
# 1      2          Chris Paul\paulch01  OKC  38506482.00 $  41358814.00 $
# 2      3  Russell Westbrook\westbru01  HOU  38178000.00 $  41006000.00 $
# 3      4           John Wall\walljo01  WAS  37800000.00 $  40824000.00 $
# 4      5       James Harden\hardeja01  HOU  37800000.00 $  40824000.00 $
# ..   ...                          ...  ...            ...            ...
# 563  564     William Howard\howarwi01  UTA     50000.00 $   1517981.00 $
# 564  565      Isaiah Taylor\taylois01  TOR     50000.00 $   1517981.00 $
# 565  566        Tyler Lydon\lydonty01  SAC     50000.00 $   1517981.00 $
# 566  567    Hollis Thompson\thompho01  SAC     50000.00 $   1517981.00 $
# 567  568          Tyler Ulis\ulisty01  SAC     50000.00 $   1517981.00 $
#
#            2021-22        2022-23        2023-24    Signed Using  \
# ...

# %% [markdown]
# SO I JUST HAVE TO DROP THE ENTIRE 2024-25 COLUMN BECAUSE THERE ARE JUST TOO MANY MISSING VALUES...
# SO YEAH THAT IS THE DATA ALL CLEANED FOR THE NEXT PERSONS TO TAKE OVER FROM

# %%
NBA.to_csv('NBA_Salary_Prediction.csv')
